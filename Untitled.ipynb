# %%
import numpy as np
import h5py
import torch
import masknmf
from masknmf.visualization.signal_selection_vis import SignalSelectionVis

# %%
file = r"X:\data\eunji\masknmf-defaults\zplane01\demixing_results.hdf5"
from masknmf.demixing.demixing_results import DemixingResults
dmr = DemixingResults.from_hdf5(file)
vis = SignalSelectionVis(dmr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 6
#       2 from masknmf.demixing.demixing_results import DemixingResults
#       3 dmr = DemixingResults.from_hdf5(file)
#       4 vis = SignalSelectionVis(dmr)
#       5 vis.show()
# ----> 6 vis.close()
#
# AttributeError: 'SignalSelectionVis' object has no attribute 'close'

# %%
import masknmf
from masknmf.visualization import SignalSelectionVis

dmr = masknmf.DemixingResults.from_hdf5(r"X:\data\eunji\masknmf-defaults\zplane01\demixing_results.hdf5")
vis = SignalSelectionVis(dmr, device="cuda")   # or SignalSelectionVis(pmd_array)
vis.show()
# Out:
# (<rendercanvas.glfw.GlfwRenderCanvas at 0x23e7b5f9910>,
#  <rendercanvas.glfw.GlfwRenderCanvas at 0x23ef201e9f0>)
